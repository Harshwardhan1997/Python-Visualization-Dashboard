# %%
pip install hvplot
# Out:
# Collecting hvplot
#   Using cached hvplot-0.8.1-py2.py3-none-any.whl (3.2 MB)
# Requirement already satisfied: holoviews>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from hvplot) (1.15.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from hvplot) (21.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from hvplot) (1.3.4)
# Requirement already satisfied: colorcet>=2 in c:\programdata\anaconda3\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: bokeh>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from hvplot) (2.4.1)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\lib\site-packages (from hvplot) (1.20.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\programdata\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\programdata\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\programdata\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.10.0.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\programdata\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (8.4.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: param<2.0,>=1.9.3 in c:\programdata\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (1.12.2)
# Requirement already satisfied: panel>=0.13.1 in c:\programdata\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (0.14.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\programdata\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->hvplot) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->hvplot) (2021.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews>=1.11.0->hvplot) (58.0.4)
# Requirement already satisfied: tqdm>=4.48.0 in c:\programdata\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews>=1.11.0->hvplot) (4.62.3)
# Requirement already satisfied: markdown in c:\programdata\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews>=1.11.0->hvplot) (3.4.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews>=1.11.0->hvplot) (2.26.0)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews>=1.11.0->hvplot) (4.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.13.1->holoviews>=1.11.0->hvplot) (0.4.4)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->panel>=0.13.1->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown->panel>=0.13.1->holoviews>=1.11.0->hvplot) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown->panel>=0.13.1->holoviews>=1.11.0->hvplot) (3.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews>=1.11.0->hvplot) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews>=1.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews>=1.11.0->hvplot) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews>=1.11.0->hvplot) (2021.10.8)
# Installing collected packages: hvplot
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\ProgramData\\Anaconda3\\Lib\\site-packages\\hvplot\\xarray.py'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)

# %%
pip install panel
# Out:
# Requirement already satisfied: panel in c:\programdata\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\programdata\anaconda3\lib\site-packages (from panel) (2.2.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from panel) (58.0.4)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from panel) (3.10.0.2)
# Requirement already satisfied: pyct>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from panel) (0.4.8)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from panel) (4.0.0)
# Requirement already satisfied: markdown in c:\programdata\anaconda3\lib\site-packages (from panel) (3.4.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\programdata\anaconda3\lib\site-packages (from panel) (4.62.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from panel) (2.26.0)
# Requirement already satisfied: param>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from panel) (1.12.2)
# Requirement already satisfied: bokeh<2.5.0,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from panel) (2.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (1.20.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (8.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (21.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (2.11.3)
# Requirement already satisfied: tornado>=5.1 in c:\programdata\anaconda3\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=16.8->bokeh<2.5.0,>=2.4.0->panel) (3.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.4)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown->panel) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown->panel) (3.6.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->panel) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->panel) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->panel) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->panel) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1949      AFG   7624058.0           NaN         NaN
# 1      Afghanistan  1950      AFG   7752117.0  9.421400e+09         NaN
# 2      Afghanistan  1951      AFG   7840151.0  9.692280e+09         NaN
# 3      Afghanistan  1952      AFG   7935996.0  1.001733e+10         NaN
# 4      Afghanistan  1953      AFG   8039684.0  1.063052e+10         NaN
# ...            ...   ...      ...         ...           ...         ...
# 26003     Zimbabwe  2016      ZWE  14030338.0  2.096179e+10       0.639
# 26004     Zimbabwe  2017      ZWE  14236599.0  2.194784e+10       0.678
# 26005     Zimbabwe  2018      ZWE  14438812.0  2.271535e+10       0.697
# 26006     Zimbabwe  2019      ZWE  14645473.0           NaN       0.697
# 26007     Zimbabwe  2020      ZWE  14862927.0           NaN       0.697
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN   0.015             NaN              NaN  ...
# 1                        NaN   0.084           0.070           475.00  ...
# 2                        NaN   0.092           0.007             8.70  ...
# 3                        NaN   0.092           0.000             0.00  ...
# 4                        NaN   0.106           0.015            16.00  ...
# ...                      ...     ...             ...              ...  ...
# 26003                  0.046  10.738          -1.488           -12.17  ...
# 26004                  0.048   9.582          -1.156           -10.77  ...
# 26005                  0.048  11.854           2.273            23.72  ...
# 26006                  0.048  10.949          -0.905            -7.64  ...
# 26007                  0.047  10.531          -0.418            -3.82  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 0                                  NaN                                NaN
# 1                                 0.00                                NaN
# 2                                 0.00                                NaN
# 3                                 0.00                                NaN
# 4                                 0.00                                NaN
# ...                                ...                                ...
# 26003                             0.02                                NaN
# 26004                             0.02                                NaN
# 26005                             0.02                                NaN
# 26006                             0.02                                NaN
# 26007                             0.03                                NaN
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                  0.00
# 2                           NaN                   NaN                  0.00
# 3                           NaN                   NaN                  0.00
# 4                           NaN                   NaN                  0.00
# ...                         ...                   ...                   ...
# 26003                       NaN                   NaN                  0.03
# 26004                       NaN                   NaN                  0.03
# 26005                       NaN                   NaN                  0.03
# 26006                       NaN                   NaN                  0.03
# 26007                       NaN                   NaN                  0.03
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         NaN        NaN                       NaN        NaN
# 1                         NaN        NaN                       NaN        NaN
# 2                         NaN        NaN                       NaN        NaN
# 3                         NaN        NaN                       NaN        NaN
# 4                         NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 26003                     NaN     115.92                     28.53      1.415
# 26004                     NaN     115.59                     28.30      1.666
# 26005                     NaN     118.22                     30.83      1.308
# 26006                     NaN     117.96                     30.53      1.473
# 26007                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 26003            13.18
# 26004            17.39
# 26005            11.04
# 26006            13.45
# 26007              NaN
#
# [26008 rows x 60 columns]

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1949      AFG   7624058.0           NaN         NaN
# 1      Afghanistan  1950      AFG   7752117.0  9.421400e+09         NaN
# 2      Afghanistan  1951      AFG   7840151.0  9.692280e+09         NaN
# 3      Afghanistan  1952      AFG   7935996.0  1.001733e+10         NaN
# 4      Afghanistan  1953      AFG   8039684.0  1.063052e+10         NaN
# ...            ...   ...      ...         ...           ...         ...
# 26003     Zimbabwe  2016      ZWE  14030338.0  2.096179e+10       0.639
# 26004     Zimbabwe  2017      ZWE  14236599.0  2.194784e+10       0.678
# 26005     Zimbabwe  2018      ZWE  14438812.0  2.271535e+10       0.697
# 26006     Zimbabwe  2019      ZWE  14645473.0           NaN       0.697
# 26007     Zimbabwe  2020      ZWE  14862927.0           NaN       0.697
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN   0.015             NaN              NaN  ...
# 1                        NaN   0.084           0.070           475.00  ...
# 2                        NaN   0.092           0.007             8.70  ...
# 3                        NaN   0.092           0.000             0.00  ...
# 4                        NaN   0.106           0.015            16.00  ...
# ...                      ...     ...             ...              ...  ...
# 26003                  0.046  10.738          -1.488           -12.17  ...
# 26004                  0.048   9.582          -1.156           -10.77  ...
# 26005                  0.048  11.854           2.273            23.72  ...
# 26006                  0.048  10.949          -0.905            -7.64  ...
# 26007                  0.047  10.531          -0.418            -3.82  ...
#
#        share_global_cumulative_oil_co2  share_global_cumulative_other_co2  \
# 0                                  NaN                                NaN
# 1                                 0.00                                NaN
# 2                                 0.00                                NaN
# 3                                 0.00                                NaN
# 4                                 0.00                                NaN
# ...                                ...                                ...
# 26003                             0.02                                NaN
# 26004                             0.02                                NaN
# 26005                             0.02                                NaN
# 26006                             0.02                                NaN
# 26007                             0.03                                NaN
#
#        share_global_flaring_co2  share_global_gas_co2  share_global_oil_co2  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                  0.00
# 2                           NaN                   NaN                  0.00
# 3                           NaN                   NaN                  0.00
# 4                           NaN                   NaN                  0.00
# ...                         ...                   ...                   ...
# 26003                       NaN                   NaN                  0.03
# 26004                       NaN                   NaN                  0.03
# 26005                       NaN                   NaN                  0.03
# 26006                       NaN                   NaN                  0.03
# 26007                       NaN                   NaN                  0.03
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 0                         NaN        NaN                       NaN        NaN
# 1                         NaN        NaN                       NaN        NaN
# 2                         NaN        NaN                       NaN        NaN
# 3                         NaN        NaN                       NaN        NaN
# 4                         NaN        NaN                       NaN        NaN
# ...                       ...        ...                       ...        ...
# 26003                     NaN     115.92                     28.53      1.415
# 26004                     NaN     115.59                     28.30      1.666
# 26005                     NaN     118.22                     30.83      1.308
# 26006                     NaN     117.96                     30.53      1.473
# 26007                     NaN        NaN                       NaN        NaN
#
#        trade_co2_share
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 26003            13.18
# 26004            17.39
# 26005            11.04
# 26006            13.45
# 26007              NaN
#
# [26008 rows x 60 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'methane', 'methane_per_capita', 'nitrous_oxide',
#        'nitrous_oxide_per_capita', 'oil_co2', 'oil_co2_per_capita',
#        'other_co2_per_capita', 'other_industry_co2',
#        'primary_energy_consumption', 'share_global_cement_co2',
#        'share_global_co2', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
#        'share_global_cumulative_other_co2', 'share_global_flaring_co2',
#        'share_global_gas_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'total_ghg', 'total_ghg_excluding_lucf',
#        'trade_co2', 'trade_co2_share'],
#       dtype='object')

# %% [markdown]
# # (0) Some minor data preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# # (1) CO2 emission over time by continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='1007'>
#
#
#
#
#
#   <div class="bk-root" id="1d38cf09-0f78-4be9-9db8-f64dbf3981ba" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ef02bff9-02c0-40d8-90c9-92f6ab5d7c05":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,5,5,5],"name":"HSpacer03113","sizing_mode":"stretch_width"},"id":"1013","type":"Spacer"},{"attributes":{"children":[{"id":"1015"}],"margin":[0,0,0,0],"name":"Row03036"},"id":"1014","type":"Row"},{"attributes":{"children":[{"id":"1009"},{"id":"1014"}],"margin":[0,0,0,0],"name":"Column03115"},"id":"1008","type":"Column"},{"attributes":{"children":[{"id":"1011"},{"id":"1012"}],"margin":[0,0,0,0],"name":"Column03031"},"id":"1010","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame03111","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1751&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n    ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent")
co2_plot
# Out:
# <div id='1221'>
#
#
#
#
#
#   <div class="bk-root" id="cdaec9f6-a864-4cbf-ba24-778bfb5e637f" data-root-id="1221"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"068028aa-6247-4d83-b5d2-8d41dfb3914e":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"line_alpha":0.2,"line_color":"#6d904f","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1345","type":"Line"},{"attributes":{"coordinates":null,"data_source":{"id":"1340"},"glyph":{"id":"1343"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"1345"},"nonselection_glyph":{"id":"1344"},"selection_glyph":{"id":"1365"},"view":{"id":"1347"}},"id":"1346","type":"GlyphRenderer"},{"attributes":{},"id":"1288","type":"UnionRenderers"},{"attributes":{"label":{"value":"North America"},"renderers":[{"id":"1346"}]},"id":"1364","type":"LegendItem"},{"attributes":{"line_color":"#8b8b8b","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1393","type":"Line"},{"attributes":{"source":{"id":"1340"}},"id":"1347","type":"CDSView"},{"attributes":{},"id":"1361","type":"UnionRenderers"},{"attributes":{"line_color":"#17becf","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1397","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#30a2da","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1277","type":"Line"},{"attributes":{"label":{"value":"Oceania"},"renderers":[{"id":"1372"}]},"id":"1392","type":"LegendItem"},{"attributes":{},"id":"1268","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"South America"},"renderers":[{"id":"1400"}]},"id":"1422","type":"LegendItem"},{"attributes":{},"id":"1269","type":"AllLabels"},{"attributes":{"line_alpha":0.2,"line_co ...

# %% [markdown]
# # (2) Table - CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='9936'>
#
#
#
#
#
#   <div class="bk-root" id="a820b266-74ae-41f3-adc9-89c6790eda29" data-root-id="9936"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"d9df4f5c-ecb5-482e-9aab-2c0b5ffd4625":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"9940"},{"id":"9941"}],"margin":[0,0,0,0],"name":"Column39533"},"id":"9939","type":"Column"},{"attributes":{"children":[{"id":"9967"}],"margin":[0,0,0,0],"name":"Row39538"},"id":"9943","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer39614","sizing_mode":"stretch_width"},"id":"9942","type":"Spacer"},{"attributes":{"client_comm_id":"35ee3a92b1bd40fd8648cc2649b4911f","comm_id":"c56c445b0f04443a9dae1234fedc037c","plot_id":"9936"},"id":"9975","type":"panel.models.comm_manager.CommManager"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year slider","value":1810},"id":"9940","type":"Slider"},{"attributes":{},"id":"9952","type":"StringFormatter"},{"attributes":{"columns":[{"id":"9949"},{"id":"9954"},{"id":"9959"},{"id":"9964"}],"configuration":{"columns":[{"field":"index","sorter":"number"},{"field":"country"},{"field":"year","sorter":"number"},{"field":"co2_per_capita","sorter":"number"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":15,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"9944"},"styles":{"data":{},"id":"4aa94cf9c92140cba521386137957ee5"},"subscribed_events":["cell-click","table-edit"],"theme_url":"https://cdn.jsdelivr.net/npm/@holoviz/panel@0.14.1/dist/bundled/datatabulator ...
#     var render_items = [{"docid":"d9df4f5c-ecb5-482e-9aab-2c0b5ffd4625","root_ids":["9936"],"roots":{"9936":"a820b266-74ae-41f3-adc9-89c6790eda29"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # (3) CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='10450'>
#
#
#
#
#
#   <div class="bk-root" id="4a894600-c319-431d-be7b-2ac705f4348a" data-root-id="10450"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"a64f6cff-21a7-4a9e-8fc2-66f093fe79ec":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,5,5,5],"name":"DataFrame43438","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Austria&lt;/td&gt;\n      &lt;td&gt;1810&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Belgium&lt;/td&gt;\n      &lt;td&gt;1810&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Canada&lt;/td&gt;\n      &lt;td&gt;1810&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;0.004&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;Europe (excl. EU-27)&lt;/td&gt;\n      &lt;td&gt;1810&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;33.291&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;European Union (27)&lt;/td&gt;\n      &lt;td&gt;1810&lt;/td&gt;\n      &lt;td&gt;0.0&lt;/td&gt;\n      &lt;td&gt;3.668&lt;/td&gt;\n    &lt;/t ...
#     var render_items = [{"docid":"a64f6cff-21a7-4a9e-8fc2-66f093fe79ec","root_ids":["10450"],"roots":{"10450":"4a894600-c319-431d-be7b-2ac705f4348a"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='10876'>
#
#
#
#
#
#   <div class="bk-root" id="9c98b914-100b-4b78-a174-b803ba7343f4" data-root-id="10876"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"0c40ef15-f50c-4c54-a2a4-24b4f997078a":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#6d904f"},"hatch_alpha":{"value":0.2},"hatch_color":{"value":"#6d904f"},"line_alpha":{"value":0.2},"line_color":{"value":"#6d904f"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"10956","type":"Scatter"},{"attributes":{},"id":"10909","type":"ResetTool"},{"attributes":{},"id":"10898","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#6d904f"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#6d904f"},"line_alpha":{"value":0.7},"line_color":{"value":"#6d904f"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"10954","type":"Scatter"},{"attributes":{"axis_label":"co2","coordinates":null,"formatter":{"id":"10922"},"group":null,"major_label_policy":{"id":"10923"},"ticker":{"id":"10902"}},"id":"10901","type":"LinearAxis"},{"attributes":{"coordinates":null,"data_source":{"id":"10933"},"glyph":{"id":"10936"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"10938"},"nonselection_glyph":{"id":"10937"},"selection_glyph":{"id":"10941"},"view":{"id":"10940"}},"id":"10939","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":0.7},"hatch_color":{"value":"#30a2da"},"line_alpha":{"value":0.7},"line_color":{"value":"#30a2da"},"size":{"value":8.94427190999916},"x":{"field":"gdp ...

# %% [markdown]
# # (4) Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='15655'>
#
#
#
#
#
#   <div class="bk-root" id="ee3c4c14-4501-4551-80c2-b4bcf16a3f62" data-root-id="15655"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"4aec222a-b652-4823-b733-4523b8c93f47":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"15670","type":"CategoricalScale"},{"attributes":{},"id":"15683","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"15658"},{"id":"15661"}],"margin":[0,0,0,0],"name":"Row50878"},"id":"15657","type":"Row"},{"attributes":{"factors":["Europe"],"tags":[[["country","country",null]]]},"id":"15662","type":"FactorRange"},{"attributes":{"children":[{"id":"15659"},{"id":"15660"}],"margin":[0,0,0,0],"name":"Column50873"},"id":"15658","type":"Column"},{"attributes":{"coordinates":null,"data_source":{"id":"15694"},"glyph":{"id":"15697"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"15699"},"nonselection_glyph":{"id":"15698"},"selection_glyph":{"id":"15702"},"view":{"id":"15701"}},"id":"15700","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"15657"},{"id":"15665"}],"margin":[0,0,0,0],"name":"Column50884"},"id":"15656","type":"Column"},{"attributes":{"axis_label":"country","coordinates":null,"formatter":{"id":"15704"},"group":null,"major_label_policy":{"id":"15705"},"ticker":{"id":"15675"}},"id":"15674","type":"CategoricalAxis"},{"attributes":{},"id":"15681","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#30a2da"},"hatch_alpha":{"value":0.1},"hatch_color":{"value":"#30a2da"},"line_alpha":{"value":0.1},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"15698","type":"VBar"},{"attributes":{},"id":"15685","type":"ResetTool"},{" ...

# %% [markdown]
# # Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('C:\\Users\\pc\\Desktop\\\kkk\\climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
#template.servable();
# Out:
# Launching server at http://localhost:49868
